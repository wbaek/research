# %%
import numpy as np
import tensorflow as tf
import tensorpack as tp

# %%
from functools import reduce
from tensorflow.python.ops import gradients_impl
from tensorflow.python.ops import array_ops, tensor_array_ops, control_flow_ops

def hessians_highrank(ys, xs, gradients=None, name="hessians", colocate_gradients_with_ops=False,
            gate_gradients=False, aggregation_method=None):
  """Constructs the Hessian (one or more rank matrix) of sum of `ys` with respect to `x` in `xs`.
  `hessians_highrank()` adds ops to the graph to output the Hessian matrix of `ys`
  with respect to `xs`.  It returns a list of `Tensor` of length `len(xs)`
  where each tensor is the Hessian of `sum(ys)`. This function currently
  only supports evaluating the Hessian with respect to (a list of) one-
  dimensional tensors.
  The Hessian is a matrix of second-order partial derivatives of a scalar
  tensor (see https://en.wikipedia.org/wiki/Hessian_matrix for more details).
  Args:
    ys: A `Tensor` or list of tensors to be differentiated.
    xs: A `Tensor` or list of tensors to be used for differentiation.
    name: Optional name to use for grouping all the gradient ops together.
      defaults to 'hessians'.
    colocate_gradients_with_ops: See `gradients()` documentation for details.
    gate_gradients: See `gradients()` documentation for details.
    aggregation_method: See `gradients()` documentation for details.
  Returns:
    A list of Hessian matrices of `sum(ys)` for each `x` in `xs`.
  Raises:
    LookupError: if one of the operations between `xs` and `ys` does not
      have a registered gradient function.
  """
  xs = gradients_impl._AsList(xs)
  kwargs = {
    'colocate_gradients_with_ops': colocate_gradients_with_ops,
    'gate_gradients': gate_gradients,
    'aggregation_method': aggregation_method
  }
  # Compute first-order derivatives and iterate for each x in xs.
  hessians = []
  _gradients = tf.gradients(ys, xs, **kwargs) if gradients is None else gradients
  for i, _gradient, x in zip(range(len(xs)), _gradients, xs):
    shape = x.shape
    _gradient = tf.reshape(_gradient, [-1])
    
    n = tf.size(x)
    loop_vars = [
      array_ops.constant(0, tf.int32),
      tensor_array_ops.TensorArray(x.dtype, n)
    ]
    _, hessian = control_flow_ops.while_loop(
      lambda j, _: j < n,
      lambda j, result: (j + 1, result.write(j, tf.gradients(_gradient[j], x)[0])),
      loop_vars
    )
    hessians.append(hessian.stack())
  return hessians

# %%
import cv2
import numpy as np
import tensorflow as tf
import tensorpack as tp

from tensorpack import dataset
from tensorpack.dataflow import imgaug, AugmentImageComponent, BatchData, PrefetchData
import tensorpack.tfutils.symbolic_functions as symbf

import tensorflow.contrib.slim as slim
from tensorflow.python.framework import ops
from tensorflow.python.training import optimizer

class ModelMNIST10x10_simple(object):
    def __init__(self, learning_rate=1.0, batch_size=128, momentum=0.9):
        self.batch_size = batch_size
        self.inputs = [
            tf.placeholder(tf.float32, shape=(None, 10, 10, 1)),
            tf.placeholder(tf.int32, shape=(None,)),
            tf.placeholder(tf.float32, shape=(None, 10))
        ]
        
        self.probability, self.cost, self.accuracy = self._build_graph(self.inputs)
        self.op = self._get_optimize_operator(self.cost, learning_rate, momentum)
        self.dataflow = {
            'train':self._get_data('train'),
            'valid':self._get_data('test'),
        }
        
    def _build_graph(self, inputs):
        image, label, vector = inputs
        
        with slim.arg_scope([slim.layers.fully_connected], weights_regularizer=slim.l2_regularizer(1e-5)):
            l = slim.layers.conv2d(image, 8, [3, 3], padding='SAME', scope='conv0' ) # 10x10
            l = slim.layers.max_pool2d(l, [2, 2], scope='pool0') # 5x5
            l = slim.layers.conv2d(l, 8, [3, 3], scope='conv1') # 3x3
            l = slim.layers.conv2d(l, 8, [3, 3], scope='conv2') # 1x1
            l = slim.layers.flatten(l, scope='flatten')
            logits = slim.layers.fully_connected(l, 10, activation_fn=None, scope='fc0')

        # Currently there is no way to take the second derivative of sparse_softmax_cross_entropy_with_logits due to the fused implementation
        #cost = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=label)
        cost = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=vector)
        cost = tf.reduce_mean(cost, name='cross_entropy_loss')

        prob = tf.nn.softmax(logits, name='prob')
        accuracy = symbf.accuracy(logits, label, topk=1)
        return prob, cost, accuracy
    
    def _get_optimize_operator(self, cost, learning_rate=1.0, momentum=0.9):
        var_list = (tf.trainable_variables() + tf.get_collection(tf.GraphKeys.TRAINABLE_RESOURCE_VARIABLES))
        var_list += tf.get_collection(tf.GraphKeys._STREAMING_MODEL_PORTS)

        processors = [optimizer._get_processor(v) for v in var_list]
        var_refs = [p.target() for p in processors]

        # compute_gradients
        grads = tf.gradients(
                cost, var_refs,
                grad_ys=None, aggregation_method=None, colocate_gradients_with_ops=True)
        hessis = hessians_highrank(
                 cost, var_refs, gradients=grads,
                 aggregation_method=None, colocate_gradients_with_ops=True)
        
        second_order_grads = []
        for g, h in zip(grads, hessis):
            shape = g.shape
            d = int(reduce(lambda a,b: a*b, shape))

            g = tf.reshape(g, [d, 1])
            h = tf.reshape(h, [d, d]) + (tf.eye(d) * 1e-1)
            h_inv = tf.matrix_inverse(h)
            grad = tf.matmul(h_inv, g)
            grad = tf.reshape(grad, shape)
            second_order_grads.append(grad)
        grads_and_vars = list(zip(second_order_grads, var_list))
        
        self.grads = grads
        
        self.global_step = tf.contrib.framework.get_or_create_global_step()
        lr_schedule = {
            'step':     [                   1],
            'rate':     [0.1*learning_rate, learning_rate],
        }
        lr_schedule['step'] = ops.convert_n_to_tensor(lr_schedule['step'], tf.int64)
        learning_rate = tf.train.piecewise_constant(self.global_step, lr_schedule['step'], lr_schedule['rate'])
        #opt = tf.train.AdamOptimizer(learning_rate)
        opt = tf.train.MomentumOptimizer(learning_rate, momentum, use_nesterov=True)
        #opt = tf.train.GradientDescentOptimizer(learning_rate)
        return opt.apply_gradients(grads_and_vars)
    
    def _get_data(self, train_or_test):
        BATCH_SIZE = self.batch_size
        isTrain = train_or_test == 'train'
        ds = dataset.Mnist(train_or_test)
        if isTrain:
            augmentors = [
                #imgaug.RandomApplyAug(imgaug.RandomResize((0.8, 1.2), (0.8, 1.2)), 0.3),
                #imgaug.RandomApplyAug(imgaug.RotationAndCropValid(15), 0.5),
                #imgaug.RandomApplyAug(imgaug.SaltPepperNoise(white_prob=0.01, black_prob=0.01), 0.25),
                imgaug.Resize((10, 10)),
                imgaug.CenterPaste((12, 12)),
                imgaug.RandomCrop((10, 10)),
                imgaug.MapImage(lambda x: x.reshape(10, 10, 1))
            ]
        else:
            augmentors = [
                imgaug.Resize((10, 10)),
                imgaug.MapImage(lambda x: x.reshape(10, 10, 1))
            ]
        ds = AugmentImageComponent(ds, augmentors)
        ds = BatchData(ds, BATCH_SIZE, remainder=not isTrain)
        if isTrain:
            ds = PrefetchData(ds, 3, 2)
        return ds

# %%
model = ModelMNIST10x10_simple(learning_rate=1.0, momentum=0.9, batch_size=128*100)
# Out:
# [1016 22:31:14 @fs.py:89] WRN Env var $TENSORPACK_DATASET not set, using /root/tensorpack_data for datasets.

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print('session initialized')
# Out:
# session initialized

# %%
import sklearn.preprocessing

history = []
for epoch in range(30):
    result = {}
    
    model.dataflow['train'].reset_state()
    step, costs, accuracies = 0, [], []
    for datapoint in model.dataflow['train'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        _, cost, accuracy, grads = sess.run([model.op, model.cost, model.accuracy, model.grads],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        grads = [np.sum(np.abs(g)) for g in grads]
        costs.append(cost)
        accuracies.append(accuracy)
        step += 1
        print('[train] epoch:%04d step:%04d cost:%.3f accuracy:%0.3f'%(epoch, step, cost, accuracy))
    print('[%04d] [train] cost:%.3f accuracy:%0.3f'%(epoch+1, np.mean(costs), np.mean(accuracies)), end=' ')
    result['train'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies), 'grads_abs':grads}

    model.dataflow['valid'].reset_state()
    costs, accuracies = [], []
    for datapoint in model.dataflow['valid'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        cost, accuracy = sess.run([model.cost, model.accuracy],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        costs.append(cost)
        accuracies.append(accuracy)
        
    print('[valid] cost:%.3f accuracy:%0.3f'%(np.mean(costs), np.mean(accuracies)))
    result['valid'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies)}
    
    history.append( result )
# Out:
# [train] epoch:0000 step:0001 cost:0.703 accuracy:0.085
# [train] epoch:0000 step:0002 cost:0.658 accuracy:0.101
# [train] epoch:0000 step:0003 cost:0.576 accuracy:0.087
# [train] epoch:0000 step:0004 cost:0.359 accuracy:0.088
# [0001] [train] cost:0.574 accuracy:0.090 [valid] cost:0.400 accuracy:0.079
# [train] epoch:0001 step:0001 cost:0.397 accuracy:0.096
# [train] epoch:0001 step:0002 cost:0.361 accuracy:0.091
# [train] epoch:0001 step:0003 cost:0.329 accuracy:0.148
# [train] epoch:0001 step:0004 cost:0.325 accuracy:0.132
# [0002] [train] cost:0.353 accuracy:0.117 [valid] cost:0.326 accuracy:0.105
# [train] epoch:0002 step:0001 cost:0.326 accuracy:0.131
# [train] epoch:0002 step:0002 cost:0.325 accuracy:0.133
# [train] epoch:0002 step:0003 cost:0.324 accuracy:0.139
# [train] epoch:0002 step:0004 cost:0.322 accuracy:0.149
# [0003] [train] cost:0.324 accuracy:0.138 [valid] cost:0.321 accuracy:0.121
# [train] epoch:0003 step:0001 cost:0.321 accuracy:0.152
# [train] epoch:0003 step:0002 cost:0.319 accuracy:0.218
# [train] epoch:0003 step:0003 cost:0.318 accuracy:0.276
# [train] epoch:0003 step:0004 cost:0.316 accuracy:0.277
# [0004] [train] cost:0.318 accuracy:0.231 [valid] cost:0.314 accuracy:0.268
# [train] epoch:0004 step:0001 cost:0.314 accuracy:0.275
# [train] epoch:0004 step:0002 cost:0.311 accuracy:0.277
# [train] epoch:0004 step:0003 cost:0.309 accuracy:0.276
# [train] epoch:0004 step:0004 cost:0.306 accuracy:0.293
# [0005] [train] cost:0.310 accuracy:0.280 [valid] cost:0.302 accuracy:0.293
# [train] epoch:0005 step:0001 cost:0.302 accuracy:0.295
# [train] epoch:0005 step:0002 cost:0.298 accuracy:0.304
# [train] epoch:0005 step:0003 cost:0.293 accuracy:0.326
# [train] epoch:0005 step:0004 cost:0.287 accuracy:0.335
# [0006] [train] cost:0.295 accuracy:0.315 [valid] cost:0.280 accuracy:0.366
# [train] epoch:0006 step:0001 cost:0.281 accuracy:0.354
# [train] epoch:0006 step:0002 cost:0.273 accuracy:0.374
# [train] epoch:0006 step:0003 cost:0.267 accuracy:0.388
# [train] epoch:0006 step:0004 cost:0.259 accuracy:0.417
# [0007] [train] cost:0.270 accuracy:0.383 [valid] cost:0.250 accuracy:0.444
# [train] epoch:0007 step:0001 cost:0.251 accuracy:0.441
# [train] epoch:0007 step:0002 cost:0.247 accuracy:0.449
# [train] epoch:0007 step:0003 cost:0.238 accuracy:0.474
# [train] epoch:0007 step:0004 cost:0.231 accuracy:0.500
# [0008] [train] cost:0.242 accuracy:0.466 [valid] cost:0.228 accuracy:0.504
# [train] epoch:0008 step:0001 cost:0.229 accuracy:0.499
# [train] epoch:0008 step:0002 cost:0.223 accuracy:0.525
# [train] epoch:0008 step:0003 cost:0.219 accuracy:0.547
# [train] epoch:0008 step:0004 cost:0.212 accuracy:0.568
# [0009] [train] cost:0.221 accuracy:0.535 [valid] cost:0.204 accuracy:0.593
# [train] epoch:0009 step:0001 cost:0.205 accuracy:0.590
# [train] epoch:0009 step:0002 cost:0.203 accuracy:0.597
# [train] epoch:0009 step:0003 cost:0.196 accuracy:0.615
# [train] epoch:0009 step:0004 cost:0.193 accuracy:0.620
# [0010] [train] cost:0.199 accuracy:0.606 [valid] cost:0.182 accuracy:0.654
# [train] epoch:0010 step:0001 cost:0.186 accuracy:0.642
# [train] epoch:0010 step:0002 cost:0.184 accuracy:0.644
# [train] epoch:0010 step:0003 cost:0.180 accuracy:0.657
# [train] epoch:0010 step:0004 cost:0.176 accuracy:0.665
# [0011] [train] cost:0.181 accuracy:0.652 [valid] cost:0.169 accuracy:0.693
# [train] epoch:0011 step:0001 cost:0.174 accuracy:0.668
# [train] epoch:0011 step:0002 cost:0.171 accuracy:0.678
# [train] epoch:0011 step:0003 cost:0.168 accuracy:0.692
# [train] epoch:0011 step:0004 cost:0.164 accuracy:0.701
# [0012] [train] cost:0.169 accuracy:0.685 [valid] cost:0.162 accuracy:0.709
# [train] epoch:0012 step:0001 cost:0.160 accuracy:0.705
# [train] epoch:0012 step:0002 cost:0.158 accuracy:0.713
# [train] epoch:0012 step:0003 cost:0.154 accuracy:0.724
# [train] epoch:0012 step:0004 cost:0.150 accuracy:0.733
# [0013] [train] cost:0.156 accuracy:0.719 [valid] cost:0.153 accuracy:0.730
# [train] epoch:0013 step:0001 cost:0.149 accuracy:0.737
# [train] epoch:0013 step:0002 cost:0.146 accuracy:0.744
# [train] epoch:0013 step:0003 cost:0.142 accuracy:0.758
# [train] epoch:0013 step:0004 cost:0.140 accuracy:0.759
# [0014] [train] cost:0.144 accuracy:0.749 [valid] cost:0.141 accuracy:0.759
# [train] epoch:0014 step:0001 cost:0.135 accuracy:0.773
# [train] epoch:0014 step:0002 cost:0.133 accuracy:0.773
# [train] epoch:0014 step:0003 cost:0.132 accuracy:0.780
# [train] epoch:0014 step:0004 cost:0.131 accuracy:0.784
# [0015] [train] cost:0.133 accuracy:0.778 [valid] cost:0.130 accuracy:0.786
# [train] epoch:0015 step:0001 cost:0.127 accuracy:0.791
# [train] epoch:0015 step:0002 cost:0.123 accuracy:0.798
# [train] epoch:0015 step:0003 cost:0.121 accuracy:0.803
# [train] epoch:0015 step:0004 cost:0.121 accuracy:0.803
# [0016] [train] cost:0.123 accuracy:0.799 [valid] cost:0.119 accuracy:0.808
# [train] epoch:0016 step:0001 cost:0.117 accuracy:0.814
# [train] epoch:0016 step:0002 cost:0.115 accuracy:0.815
# [train] epoch:0016 step:0003 cost:0.112 accuracy:0.822
# [train] epoch:0016 step:0004 cost:0.111 accuracy:0.825
# [0017] [train] cost:0.114 accuracy:0.819 [valid] cost:0.110 accuracy:0.827
# [train] epoch:0017 step:0001 cost:0.109 accuracy:0.827
# [train] epoch:0017 step:0002 cost:0.107 accuracy:0.833
# [train] epoch:0017 step:0003 cost:0.105 accuracy:0.835
# [train] epoch:0017 step:0004 cost:0.105 accuracy:0.835
# [0018] [train] cost:0.106 accuracy:0.832 [valid] cost:0.100 accuracy:0.843
# [train] epoch:0018 step:0001 cost:0.102 accuracy:0.840
# [train] epoch:0018 step:0002 cost:0.097 accuracy:0.851
# [train] epoch:0018 step:0003 cost:0.099 accuracy:0.842
# [train] epoch:0018 step:0004 cost:0.098 accuracy:0.844
# [0019] [train] cost:0.099 accuracy:0.844 [valid] cost:0.093 accuracy:0.855
# [train] epoch:0019 step:0001 cost:0.095 accuracy:0.849
# [train] epoch:0019 step:0002 cost:0.095 accuracy:0.851
# [train] epoch:0019 step:0003 cost:0.094 accuracy:0.851
# [train] epoch:0019 step:0004 cost:0.094 accuracy:0.854
# [0020] [train] cost:0.095 accuracy:0.851 [valid] cost:0.089 accuracy:0.865
# [train] epoch:0020 step:0001 cost:0.090 accuracy:0.861
# [train] epoch:0020 step:0002 cost:0.090 accuracy:0.862
# [train] epoch:0020 step:0003 cost:0.090 accuracy:0.861
# [train] epoch:0020 step:0004 cost:0.088 accuracy:0.864
# [0021] [train] cost:0.089 accuracy:0.862 [valid] cost:0.085 accuracy:0.872
# [train] epoch:0021 step:0001 cost:0.086 accuracy:0.866
# [train] epoch:0021 step:0002 cost:0.087 accuracy:0.866
# [train] epoch:0021 step:0003 cost:0.086 accuracy:0.867
# [train] epoch:0021 step:0004 cost:0.085 accuracy:0.867
# [0022] [train] cost:0.086 accuracy:0.866 [valid] cost:0.082 accuracy:0.874
# [train] epoch:0022 step:0001 cost:0.086 accuracy:0.868
# [train] epoch:0022 step:0002 cost:0.084 accuracy:0.871
# [train] epoch:0022 step:0003 cost:0.082 accuracy:0.876
# [train] epoch:0022 step:0004 cost:0.081 accuracy:0.875
# [0023] [train] cost:0.083 accuracy:0.873 [valid] cost:0.079 accuracy:0.879
# [train] epoch:0023 step:0001 cost:0.081 accuracy:0.874
# [train] epoch:0023 step:0002 cost:0.082 accuracy:0.877
# [train] epoch:0023 step:0003 cost:0.079 accuracy:0.880
# [train] epoch:0023 step:0004 cost:0.080 accuracy:0.879
# [0024] [train] cost:0.081 accuracy:0.877 [valid] cost:0.077 accuracy:0.882
# [train] epoch:0024 step:0001 cost:0.079 accuracy:0.879
# [train] epoch:0024 step:0002 cost:0.078 accuracy:0.879
# [train] epoch:0024 step:0003 cost:0.077 accuracy:0.882
# [train] epoch:0024 step:0004 cost:0.077 accuracy:0.881
# [0025] [train] cost:0.078 accuracy:0.880 [valid] cost:0.076 accuracy:0.886
# [train] epoch:0025 step:0001 cost:0.076 accuracy:0.887
# [train] epoch:0025 step:0002 cost:0.076 accuracy:0.886
# [train] epoch:0025 step:0003 cost:0.075 accuracy:0.887
# [train] epoch:0025 step:0004 cost:0.075 accuracy:0.887
# [0026] [train] cost:0.075 accuracy:0.887 [valid] cost:0.074 accuracy:0.890
# [train] epoch:0026 step:0001 cost:0.075 accuracy:0.889
# [train] epoch:0026 step:0002 cost:0.075 accuracy:0.887
# [train] epoch:0026 step:0003 cost:0.072 accuracy:0.890
# [train] epoch:0026 step:0004 cost:0.074 accuracy:0.888
# [0027] [train] cost:0.074 accuracy:0.889 [valid] cost:0.072 accuracy:0.892
# [train] epoch:0027 step:0001 cost:0.073 accuracy:0.890
# [train] epoch:0027 step:0002 cost:0.073 accuracy:0.893
# [train] epoch:0027 step:0003 cost:0.074 accuracy:0.890
# [train] epoch:0027 step:0004 cost:0.071 accuracy:0.890
# [0028] [train] cost:0.073 accuracy:0.891 [valid] cost:0.070 accuracy:0.895
# [train] epoch:0028 step:0001 cost:0.071 accuracy:0.894
# [train] epoch:0028 step:0002 cost:0.070 accuracy:0.897
# [train] epoch:0028 step:0003 cost:0.071 accuracy:0.892
# [train] epoch:0028 step:0004 cost:0.070 accuracy:0.893
# [0029] [train] cost:0.070 accuracy:0.894 [valid] cost:0.069 accuracy:0.898
# [train] epoch:0029 step:0001 cost:0.071 accuracy:0.894
# [train] epoch:0029 step:0002 cost:0.071 accuracy:0.894
# [train] epoch:0029 step:0003 cost:0.069 accuracy:0.895
# [train] epoch:0029 step:0004 cost:0.069 accuracy:0.893
# [0030] [train] cost:0.070 accuracy:0.894 [valid] cost:0.068 accuracy:0.900
