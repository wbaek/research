# %%
import numpy as np
import tensorflow as tf
import tensorpack as tp

# %%
from functools import reduce
from tensorflow.python.ops import gradients_impl
from tensorflow.python.ops import array_ops, tensor_array_ops, control_flow_ops

def hessians_highrank(ys, xs, gradients=None, name="hessians", colocate_gradients_with_ops=False,
            gate_gradients=False, aggregation_method=None):
  """Constructs the Hessian (one or more rank matrix) of sum of `ys` with respect to `x` in `xs`.
  `hessians_highrank()` adds ops to the graph to output the Hessian matrix of `ys`
  with respect to `xs`.  It returns a list of `Tensor` of length `len(xs)`
  where each tensor is the Hessian of `sum(ys)`. This function currently
  only supports evaluating the Hessian with respect to (a list of) one-
  dimensional tensors.
  The Hessian is a matrix of second-order partial derivatives of a scalar
  tensor (see https://en.wikipedia.org/wiki/Hessian_matrix for more details).
  Args:
    ys: A `Tensor` or list of tensors to be differentiated.
    xs: A `Tensor` or list of tensors to be used for differentiation.
    name: Optional name to use for grouping all the gradient ops together.
      defaults to 'hessians'.
    colocate_gradients_with_ops: See `gradients()` documentation for details.
    gate_gradients: See `gradients()` documentation for details.
    aggregation_method: See `gradients()` documentation for details.
  Returns:
    A list of Hessian matrices of `sum(ys)` for each `x` in `xs`.
  Raises:
    LookupError: if one of the operations between `xs` and `ys` does not
      have a registered gradient function.
  """
  xs = gradients_impl._AsList(xs)
  kwargs = {
    'colocate_gradients_with_ops': colocate_gradients_with_ops,
    'gate_gradients': gate_gradients,
    'aggregation_method': aggregation_method
  }
  # Compute first-order derivatives and iterate for each x in xs.
  hessians = []
  _gradients = tf.gradients(ys, xs, **kwargs) if gradients is None else gradients
  for i, _gradient, x in zip(range(len(xs)), _gradients, xs):
    shape = x.shape
    _gradient = tf.reshape(_gradient, [-1])
    
    n = tf.size(x)
    loop_vars = [
      array_ops.constant(0, tf.int32),
      tensor_array_ops.TensorArray(x.dtype, n)
    ]
    _, hessian = control_flow_ops.while_loop(
      lambda j, _: j < n,
      lambda j, result: (j + 1, result.write(j, tf.gradients(_gradient[j], x)[0])),
      loop_vars
    )
    hessians.append(hessian.stack())
  return hessians

# %%
import cv2
import numpy as np
import tensorflow as tf
import tensorpack as tp

from tensorpack import dataset
from tensorpack.dataflow import imgaug, AugmentImageComponent, BatchData, PrefetchData
import tensorpack.tfutils.symbolic_functions as symbf

import tensorflow.contrib.slim as slim
from tensorflow.python.framework import ops
from tensorflow.python.training import optimizer

class ModelMNIST10x10_simple(object):
    def __init__(self, learning_rate=1.0, batch_size=128, momentum=0.9):
        self.batch_size = batch_size
        self.inputs = [
            tf.placeholder(tf.float32, shape=(None, 10, 10, 1)),
            tf.placeholder(tf.int32, shape=(None,)),
            tf.placeholder(tf.float32, shape=(None, 10))
        ]
        
        self.probability, self.cost, self.accuracy = self._build_graph(self.inputs)
        self.op = self._get_optimize_operator(self.cost, learning_rate, momentum)
        self.dataflow = {
            'train':self._get_data('train'),
            'valid':self._get_data('test'),
        }
        
    def _build_graph(self, inputs):
        image, label, vector = inputs
        
        with slim.arg_scope([slim.layers.fully_connected], weights_regularizer=slim.l2_regularizer(1e-5)):
            l = slim.layers.conv2d(image, 8, [3, 3], padding='SAME', scope='conv0' ) # 10x10
            l = slim.layers.max_pool2d(l, [2, 2], scope='pool0') # 5x5
            l = slim.layers.conv2d(l, 8, [3, 3], scope='conv1') # 3x3
            l = slim.layers.conv2d(l, 8, [3, 3], scope='conv2') # 1x1
            l = slim.layers.flatten(l, scope='flatten')
            logits = slim.layers.fully_connected(l, 10, activation_fn=None, scope='fc0')

        # Currently there is no way to take the second derivative of sparse_softmax_cross_entropy_with_logits due to the fused implementation
        #cost = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=label)
        cost = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=vector)
        cost = tf.reduce_mean(cost, name='cross_entropy_loss')

        prob = tf.nn.softmax(logits, name='prob')
        accuracy = symbf.accuracy(logits, label, topk=1)
        return prob, cost, accuracy
    
    def _get_optimize_operator(self, cost, learning_rate=1.0, momentum=0.9):
        var_list = (tf.trainable_variables() + tf.get_collection(tf.GraphKeys.TRAINABLE_RESOURCE_VARIABLES))
        var_list += tf.get_collection(tf.GraphKeys._STREAMING_MODEL_PORTS)

        processors = [optimizer._get_processor(v) for v in var_list]
        var_refs = [p.target() for p in processors]

        # compute_gradients
        grads = tf.gradients(
                cost, var_refs,
                grad_ys=None, aggregation_method=None, colocate_gradients_with_ops=True)
        hessis = hessians_highrank(
                 cost, var_refs, gradients=grads,
                 aggregation_method=None, colocate_gradients_with_ops=True)
        
        second_order_grads = []
        for g, h in zip(grads, hessis):
            shape = g.shape
            d = int(reduce(lambda a,b: a*b, shape))

            g = tf.reshape(g, [d, 1])
            h = tf.reshape(h, [d, d]) + (tf.eye(d) * 1e-1)
            h_inv = tf.matrix_inverse(h)
            grad = tf.matmul(h_inv, g)
            grad = tf.reshape(grad, shape)
            second_order_grads.append(grad)
        grads_and_vars = list(zip(second_order_grads, var_list))
        
        self.grads = grads
        
        self.global_step = tf.contrib.framework.get_or_create_global_step()
        lr_schedule = {
            'step':     [                   1],
            'rate':     [0.1*learning_rate, learning_rate],
        }
        lr_schedule['step'] = ops.convert_n_to_tensor(lr_schedule['step'], tf.int64)
        learning_rate = tf.train.piecewise_constant(self.global_step, lr_schedule['step'], lr_schedule['rate'])
        #opt = tf.train.AdamOptimizer(learning_rate)
        opt = tf.train.MomentumOptimizer(learning_rate, momentum, use_nesterov=True)
        #opt = tf.train.GradientDescentOptimizer(learning_rate)
        return opt.apply_gradients(grads_and_vars)
    
    def _get_data(self, train_or_test):
        BATCH_SIZE = self.batch_size
        isTrain = train_or_test == 'train'
        ds = dataset.Mnist(train_or_test)
        if isTrain:
            augmentors = [
                #imgaug.RandomApplyAug(imgaug.RandomResize((0.8, 1.2), (0.8, 1.2)), 0.3),
                #imgaug.RandomApplyAug(imgaug.RotationAndCropValid(15), 0.5),
                #imgaug.RandomApplyAug(imgaug.SaltPepperNoise(white_prob=0.01, black_prob=0.01), 0.25),
                imgaug.Resize((10, 10)),
                imgaug.CenterPaste((12, 12)),
                imgaug.RandomCrop((10, 10)),
                imgaug.MapImage(lambda x: x.reshape(10, 10, 1))
            ]
        else:
            augmentors = [
                imgaug.Resize((10, 10)),
                imgaug.MapImage(lambda x: x.reshape(10, 10, 1))
            ]
        ds = AugmentImageComponent(ds, augmentors)
        ds = BatchData(ds, BATCH_SIZE, remainder=not isTrain)
        if isTrain:
            ds = PrefetchData(ds, 3, 2)
        return ds

# %%
model = ModelMNIST10x10_simple(learning_rate=0.9, momentum=0.9, batch_size=50000)
# Out:
# [1017 00:41:34 @fs.py:89] WRN Env var $TENSORPACK_DATASET not set, using /root/tensorpack_data for datasets.

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print('session initialized')
# Out:
# session initialized

# %%
import sklearn.preprocessing

history = []
for epoch in range(100):
    result = {}
    
    model.dataflow['train'].reset_state()
    step, costs, accuracies = 0, [], []
    for datapoint in model.dataflow['train'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        _, cost, accuracy, grads = sess.run([model.op, model.cost, model.accuracy, model.grads],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        grads = [np.sum(np.abs(g)) for g in grads]
        costs.append(cost)
        accuracies.append(accuracy)
        step += 1
        #print('[train] epoch:%04d step:%04d cost:%.3f accuracy:%0.3f'%(epoch, step, cost, accuracy))
    print('[%04d] [train] cost:%.3f accuracy:%0.3f'%(epoch+1, np.mean(costs), np.mean(accuracies)), end=' ')
    result['train'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies), 'grads_abs':grads}

    model.dataflow['valid'].reset_state()
    costs, accuracies = [], []
    for datapoint in model.dataflow['valid'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        cost, accuracy = sess.run([model.cost, model.accuracy],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        costs.append(cost)
        accuracies.append(accuracy)
        
    print('[valid] cost:%.3f accuracy:%0.3f'%(np.mean(costs), np.mean(accuracies)))
    result['valid'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies)}
    
    history.append( result )
# Out:
# [0001] [train] cost:0.717 accuracy:0.089 [valid] cost:0.652 accuracy:0.074
# [0002] [train] cost:0.648 accuracy:0.098 [valid] cost:0.552 accuracy:0.079
# [0003] [train] cost:0.550 accuracy:0.104 [valid] cost:0.360 accuracy:0.087
# [0004] [train] cost:0.361 accuracy:0.092 [valid] cost:0.374 accuracy:0.087
# [0005] [train] cost:0.371 accuracy:0.091 [valid] cost:0.391 accuracy:0.082
# [0006] [train] cost:0.387 accuracy:0.110 [valid] cost:0.335 accuracy:0.118
# [0007] [train] cost:0.333 accuracy:0.123 [valid] cost:0.324 accuracy:0.103
# [0008] [train] cost:0.324 accuracy:0.144 [valid] cost:0.323 accuracy:0.081
# [0009] [train] cost:0.323 accuracy:0.137 [valid] cost:0.322 accuracy:0.088
# [0010] [train] cost:0.323 accuracy:0.152 [valid] cost:0.321 accuracy:0.111
# [0011] [train] cost:0.321 accuracy:0.159 [valid] cost:0.319 accuracy:0.126
# [0012] [train] cost:0.319 accuracy:0.163 [valid] cost:0.318 accuracy:0.141
# [0013] [train] cost:0.318 accuracy:0.177 [valid] cost:0.317 accuracy:0.228
# [0014] [train] cost:0.317 accuracy:0.252 [valid] cost:0.315 accuracy:0.312
# [0015] [train] cost:0.315 accuracy:0.319 [valid] cost:0.313 accuracy:0.318
# [0016] [train] cost:0.313 accuracy:0.344 [valid] cost:0.310 accuracy:0.320
# [0017] [train] cost:0.311 accuracy:0.354 [valid] cost:0.308 accuracy:0.322
# [0018] [train] cost:0.308 accuracy:0.357 [valid] cost:0.304 accuracy:0.328
# [0019] [train] cost:0.305 accuracy:0.358 [valid] cost:0.300 accuracy:0.337
# [0020] [train] cost:0.300 accuracy:0.362 [valid] cost:0.295 accuracy:0.344
# [0021] [train] cost:0.295 accuracy:0.370 [valid] cost:0.289 accuracy:0.350
# [0022] [train] cost:0.289 accuracy:0.374 [valid] cost:0.283 accuracy:0.361
# [0023] [train] cost:0.283 accuracy:0.385 [valid] cost:0.275 accuracy:0.380
# [0024] [train] cost:0.275 accuracy:0.404 [valid] cost:0.267 accuracy:0.408
# [0025] [train] cost:0.267 accuracy:0.426 [valid] cost:0.258 accuracy:0.443
# [0026] [train] cost:0.258 accuracy:0.449 [valid] cost:0.248 accuracy:0.478
# [0027] [train] cost:0.249 accuracy:0.476 [valid] cost:0.238 accuracy:0.514
# [0028] [train] cost:0.239 accuracy:0.502 [valid] cost:0.229 accuracy:0.538
# [0029] [train] cost:0.230 accuracy:0.522 [valid] cost:0.222 accuracy:0.558
# [0030] [train] cost:0.223 accuracy:0.539 [valid] cost:0.217 accuracy:0.572
# [0031] [train] cost:0.216 accuracy:0.559 [valid] cost:0.214 accuracy:0.583
# [0032] [train] cost:0.211 accuracy:0.575 [valid] cost:0.211 accuracy:0.592
# [0033] [train] cost:0.208 accuracy:0.585 [valid] cost:0.208 accuracy:0.602
# [0034] [train] cost:0.204 accuracy:0.602 [valid] cost:0.204 accuracy:0.613
# [0035] [train] cost:0.201 accuracy:0.613 [valid] cost:0.199 accuracy:0.625
# [0036] [train] cost:0.195 accuracy:0.627 [valid] cost:0.193 accuracy:0.638
# [0037] [train] cost:0.190 accuracy:0.643 [valid] cost:0.188 accuracy:0.649
# [0038] [train] cost:0.185 accuracy:0.652 [valid] cost:0.183 accuracy:0.659
# [0039] [train] cost:0.180 accuracy:0.663 [valid] cost:0.179 accuracy:0.669
# [0040] [train] cost:0.176 accuracy:0.670 [valid] cost:0.175 accuracy:0.676
# [0041] [train] cost:0.172 accuracy:0.682 [valid] cost:0.172 accuracy:0.683
# [0042] [train] cost:0.169 accuracy:0.689 [valid] cost:0.170 accuracy:0.688
# [0043] [train] cost:0.166 accuracy:0.698 [valid] cost:0.167 accuracy:0.695
# [0044] [train] cost:0.163 accuracy:0.701 [valid] cost:0.165 accuracy:0.703
# [0045] [train] cost:0.160 accuracy:0.708 [valid] cost:0.162 accuracy:0.709
# [0046] [train] cost:0.158 accuracy:0.714 [valid] cost:0.159 accuracy:0.715
# [0047] [train] cost:0.154 accuracy:0.723 [valid] cost:0.157 accuracy:0.724
# [0048] [train] cost:0.152 accuracy:0.728 [valid] cost:0.154 accuracy:0.732
# [0049] [train] cost:0.149 accuracy:0.736 [valid] cost:0.150 accuracy:0.743
# [0050] [train] cost:0.146 accuracy:0.740 [valid] cost:0.147 accuracy:0.752
# [0051] [train] cost:0.144 accuracy:0.746 [valid] cost:0.144 accuracy:0.758
# [0052] [train] cost:0.140 accuracy:0.757 [valid] cost:0.140 accuracy:0.766
# [0053] [train] cost:0.138 accuracy:0.759 [valid] cost:0.137 accuracy:0.773
# [0054] [train] cost:0.135 accuracy:0.766 [valid] cost:0.134 accuracy:0.781
# [0055] [train] cost:0.132 accuracy:0.773 [valid] cost:0.131 accuracy:0.786
# [0056] [train] cost:0.130 accuracy:0.777 [valid] cost:0.128 accuracy:0.790
# [0057] [train] cost:0.128 accuracy:0.782 [valid] cost:0.125 accuracy:0.796
# [0058] [train] cost:0.125 accuracy:0.784 [valid] cost:0.122 accuracy:0.803
# [0059] [train] cost:0.123 accuracy:0.793 [valid] cost:0.120 accuracy:0.807
# [0060] [train] cost:0.121 accuracy:0.796 [valid] cost:0.117 accuracy:0.810
# [0061] [train] cost:0.120 accuracy:0.799 [valid] cost:0.115 accuracy:0.815
# [0062] [train] cost:0.117 accuracy:0.804 [valid] cost:0.113 accuracy:0.820
# [0063] [train] cost:0.116 accuracy:0.807 [valid] cost:0.111 accuracy:0.823
# [0064] [train] cost:0.114 accuracy:0.810 [valid] cost:0.109 accuracy:0.825
# [0065] [train] cost:0.112 accuracy:0.816 [valid] cost:0.108 accuracy:0.828
# [0066] [train] cost:0.110 accuracy:0.821 [valid] cost:0.106 accuracy:0.831
# [0067] [train] cost:0.109 accuracy:0.823 [valid] cost:0.104 accuracy:0.834
# [0068] [train] cost:0.106 accuracy:0.827 [valid] cost:0.103 accuracy:0.836
# [0069] [train] cost:0.106 accuracy:0.830 [valid] cost:0.101 accuracy:0.838
# [0070] [train] cost:0.104 accuracy:0.832 [valid] cost:0.100 accuracy:0.841
# [0071] [train] cost:0.103 accuracy:0.835 [valid] cost:0.099 accuracy:0.843
# [0072] [train] cost:0.101 accuracy:0.837 [valid] cost:0.098 accuracy:0.846
# [0073] [train] cost:0.101 accuracy:0.840 [valid] cost:0.096 accuracy:0.849
# [0074] [train] cost:0.099 accuracy:0.844 [valid] cost:0.095 accuracy:0.851
# [0075] [train] cost:0.097 accuracy:0.848 [valid] cost:0.094 accuracy:0.852
# [0076] [train] cost:0.097 accuracy:0.848 [valid] cost:0.093 accuracy:0.853
# [0077] [train] cost:0.095 accuracy:0.850 [valid] cost:0.092 accuracy:0.855
# [0078] [train] cost:0.094 accuracy:0.853 [valid] cost:0.091 accuracy:0.857
# [0079] [train] cost:0.093 accuracy:0.855 [valid] cost:0.090 accuracy:0.859
# [0080] [train] cost:0.092 accuracy:0.858 [valid] cost:0.089 accuracy:0.861
# [0081] [train] cost:0.092 accuracy:0.857 [valid] cost:0.088 accuracy:0.863
# [0082] [train] cost:0.090 accuracy:0.862 [valid] cost:0.087 accuracy:0.866
# [0083] [train] cost:0.089 accuracy:0.864 [valid] cost:0.086 accuracy:0.867
# [0084] [train] cost:0.088 accuracy:0.864 [valid] cost:0.085 accuracy:0.869
# [0085] [train] cost:0.087 accuracy:0.868 [valid] cost:0.085 accuracy:0.871
# [0086] [train] cost:0.087 accuracy:0.869 [valid] cost:0.084 accuracy:0.872
# [0087] [train] cost:0.086 accuracy:0.869 [valid] cost:0.083 accuracy:0.873
# [0088] [train] cost:0.086 accuracy:0.870 [valid] cost:0.082 accuracy:0.874
# [0089] [train] cost:0.085 accuracy:0.873 [valid] cost:0.082 accuracy:0.874
# [0090] [train] cost:0.084 accuracy:0.874 [valid] cost:0.081 accuracy:0.876
# [0091] [train] cost:0.083 accuracy:0.874 [valid] cost:0.080 accuracy:0.877
# [0092] [train] cost:0.083 accuracy:0.876 [valid] cost:0.080 accuracy:0.878
# [0093] [train] cost:0.082 accuracy:0.877 [valid] cost:0.079 accuracy:0.880
# [0094] [train] cost:0.081 accuracy:0.879 [valid] cost:0.078 accuracy:0.881
# [0095] [train] cost:0.081 accuracy:0.878 [valid] cost:0.078 accuracy:0.881
# [0096] [train] cost:0.080 accuracy:0.880 [valid] cost:0.077 accuracy:0.883
# [0097] [train] cost:0.080 accuracy:0.880 [valid] cost:0.076 accuracy:0.885
# [0098] [train] cost:0.078 accuracy:0.883 [valid] cost:0.076 accuracy:0.886
# [0099] [train] cost:0.078 accuracy:0.884 [valid] cost:0.075 accuracy:0.887
# [0100] [train] cost:0.078 accuracy:0.886 [valid] cost:0.075 accuracy:0.887

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(12, 4*3))
for i, label in enumerate(['cost', 'accuracy', 'grads_abs']):
    ax = fig.add_subplot(3, 1, i+1)
    ax.set_xlabel('epoch', fontsize=12)
    ax.set_ylabel(label, fontsize=12)
    ax.set_title(label, fontsize=12)
    for j, mode in enumerate(['train', 'valid']):
        if not label in history[0][mode]:
            continue
        ax.plot(np.array([h[mode]['epoch'] for h in history]), np.array([np.sum(h[mode][label]) for h in history]), label=mode)
    ax.legend()
plt.tight_layout()

# %%
for epoch in range(50):
    result = {}
    
    model.dataflow['train'].reset_state()
    step, costs, accuracies = 0, [], []
    for datapoint in model.dataflow['train'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        _, cost, accuracy, grads = sess.run([model.op, model.cost, model.accuracy, model.grads],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        grads = [np.sum(np.abs(g)) for g in grads]
        costs.append(cost)
        accuracies.append(accuracy)
        step += 1
        #print('[train] epoch:%04d step:%04d cost:%.3f accuracy:%0.3f'%(epoch, step, cost, accuracy))
    print('[%04d] [train] cost:%.3f accuracy:%0.3f'%(epoch+1, np.mean(costs), np.mean(accuracies)), end=' ')
    result['train'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies), 'grads_abs':grads}

    model.dataflow['valid'].reset_state()
    costs, accuracies = [], []
    for datapoint in model.dataflow['valid'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        cost, accuracy = sess.run([model.cost, model.accuracy],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        costs.append(cost)
        accuracies.append(accuracy)
        
    print('[valid] cost:%.3f accuracy:%0.3f'%(np.mean(costs), np.mean(accuracies)))
    result['valid'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies)}
    
    history.append( result )
# Out:
# [0001] [train] cost:0.077 accuracy:0.887 [valid] cost:0.074 accuracy:0.888
# [0002] [train] cost:0.076 accuracy:0.887 [valid] cost:0.074 accuracy:0.889
# [0003] [train] cost:0.076 accuracy:0.888 [valid] cost:0.073 accuracy:0.889
# [0004] [train] cost:0.075 accuracy:0.890 [valid] cost:0.073 accuracy:0.889
# [0005] [train] cost:0.074 accuracy:0.890 [valid] cost:0.072 accuracy:0.890
# [0006] [train] cost:0.074 accuracy:0.891 [valid] cost:0.072 accuracy:0.891
# [0007] [train] cost:0.074 accuracy:0.890 [valid] cost:0.072 accuracy:0.891
# [0008] [train] cost:0.073 accuracy:0.892 [valid] cost:0.071 accuracy:0.892
# [0009] [train] cost:0.072 accuracy:0.894 [valid] cost:0.071 accuracy:0.894
# [0010] [train] cost:0.072 accuracy:0.894 [valid] cost:0.070 accuracy:0.895
# [0011] [train] cost:0.072 accuracy:0.894 [valid] cost:0.070 accuracy:0.895
# [0012] [train] cost:0.071 accuracy:0.895 [valid] cost:0.069 accuracy:0.896
# [0013] [train] cost:0.071 accuracy:0.896 [valid] cost:0.069 accuracy:0.897
# [0014] [train] cost:0.070 accuracy:0.897 [valid] cost:0.069 accuracy:0.897
# [0015] [train] cost:0.070 accuracy:0.897 [valid] cost:0.068 accuracy:0.898
# [0016] [train] cost:0.069 accuracy:0.901 [valid] cost:0.068 accuracy:0.898
# [0017] [train] cost:0.069 accuracy:0.899 [valid] cost:0.068 accuracy:0.899
# [0018] [train] cost:0.070 accuracy:0.898 [valid] cost:0.067 accuracy:0.899
# [0019] [train] cost:0.069 accuracy:0.900 [valid] cost:0.067 accuracy:0.900
# [0020] [train] cost:0.068 accuracy:0.901 [valid] cost:0.067 accuracy:0.900
# [0021] [train] cost:0.068 accuracy:0.901 [valid] cost:0.066 accuracy:0.900
# [0022] [train] cost:0.067 accuracy:0.901 [valid] cost:0.066 accuracy:0.901
# [0023] [train] cost:0.067 accuracy:0.902 [valid] cost:0.066 accuracy:0.902
# [0024] [train] cost:0.066 accuracy:0.902 [valid] cost:0.065 accuracy:0.903
# [0025] [train] cost:0.066 accuracy:0.903 [valid] cost:0.065 accuracy:0.903
# [0026] [train] cost:0.067 accuracy:0.903 [valid] cost:0.065 accuracy:0.903
# [0027] [train] cost:0.065 accuracy:0.906 [valid] cost:0.064 accuracy:0.904
# [0028] [train] cost:0.066 accuracy:0.905 [valid] cost:0.064 accuracy:0.905
# [0029] [train] cost:0.065 accuracy:0.906 [valid] cost:0.064 accuracy:0.906
# [0030] [train] cost:0.064 accuracy:0.907 [valid] cost:0.063 accuracy:0.906
# [0031] [train] cost:0.065 accuracy:0.907 [valid] cost:0.063 accuracy:0.907
# [0032] [train] cost:0.065 accuracy:0.907 [valid] cost:0.063 accuracy:0.908
# [0033] [train] cost:0.064 accuracy:0.908 [valid] cost:0.063 accuracy:0.909
# [0034] [train] cost:0.064 accuracy:0.907 [valid] cost:0.062 accuracy:0.910
# [0035] [train] cost:0.063 accuracy:0.908 [valid] cost:0.062 accuracy:0.910
# [0036] [train] cost:0.063 accuracy:0.910 [valid] cost:0.062 accuracy:0.911
# [0037] [train] cost:0.063 accuracy:0.909 [valid] cost:0.062 accuracy:0.912
# [0038] [train] cost:0.062 accuracy:0.912 [valid] cost:0.061 accuracy:0.912
# [0039] [train] cost:0.062 accuracy:0.912 [valid] cost:0.061 accuracy:0.913
# [0040] [train] cost:0.062 accuracy:0.910 [valid] cost:0.061 accuracy:0.913
# [0041] [train] cost:0.061 accuracy:0.913 [valid] cost:0.061 accuracy:0.914
# [0042] [train] cost:0.061 accuracy:0.912 [valid] cost:0.060 accuracy:0.913
# [0043] [train] cost:0.061 accuracy:0.912 [valid] cost:0.060 accuracy:0.914
# [0044] [train] cost:0.061 accuracy:0.914 [valid] cost:0.060 accuracy:0.914
# [0045] [train] cost:0.060 accuracy:0.913 [valid] cost:0.060 accuracy:0.915
# [0046] [train] cost:0.061 accuracy:0.913 [valid] cost:0.059 accuracy:0.915
# [0047] [train] cost:0.061 accuracy:0.913 [valid] cost:0.059 accuracy:0.915
# [0048] [train] cost:0.060 accuracy:0.915 [valid] cost:0.059 accuracy:0.915
# [0049] [train] cost:0.059 accuracy:0.914 [valid] cost:0.059 accuracy:0.915
# [0050] [train] cost:0.060 accuracy:0.915 [valid] cost:0.058 accuracy:0.916

# %%
fig = plt.figure(figsize=(12, 4*3))
for i, label in enumerate(['cost', 'accuracy', 'grads_abs']):
    ax = fig.add_subplot(3, 1, i+1)
    ax.set_xlabel('epoch', fontsize=12)
    ax.set_ylabel(label, fontsize=12)
    ax.set_title(label, fontsize=12)
    for j, mode in enumerate(['train', 'valid']):
        if not label in history[0][mode]:
            continue
        ax.plot(np.array(range(len(history))), np.array([np.sum(h[mode][label]) for h in history]), label=mode)
    ax.legend()
plt.tight_layout()
