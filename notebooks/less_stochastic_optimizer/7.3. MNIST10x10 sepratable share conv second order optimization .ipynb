# %%
import numpy as np
import tensorflow as tf
import tensorpack as tp

# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim

def depthwise_conv2d_splite_share(input_tensor, kernel_size, strides=[1, 1], padding='VALID', activation_fn=None, scope=None):
    axis = 3
    shape = [-1] + [int(s) for s in input_tensor.shape[1:]]

    splited = [tf.reshape(t, [shape[0], shape[1], shape[2], 1]) for t in tf.unstack(input_tensor, axis=axis)]
    
    splited_out = []
    for i, t in enumerate(splited):
        o = slim.layers.conv2d(t, 1, [3, 3], padding=padding, activation_fn=activation_fn, scope=scope, reuse=(i>0))
        splited_out.append(tf.squeeze(o, [axis]))
    
    result = tf.stack(splited_out, axis=axis)
    return result

def depthwise_conv2d_splite(input_tensor, kernel_size, strides=[1, 1], padding='VALID', activation_fn=None, scope=None):
    axis = 3
    shape = [-1] + [int(s) for s in input_tensor.shape[1:]]

    splited = [tf.reshape(t, [shape[0], shape[1], shape[2], 1]) for t in tf.unstack(input_tensor, axis=axis)]
    
    splited_out = []
    for i, t in enumerate(splited):
        o = slim.layers.conv2d(t, 1, [3, 3], padding=padding, activation_fn=activation_fn, scope=scope+'_'+str(i))
        splited_out.append(tf.squeeze(o, [axis]))
    
    result = tf.stack(splited_out, axis=axis)
    return result

def pointwise_conv2d(input_tensor, filters, activation_fn=None, scope=None):
    return slim.layers.conv2d(input_tensor, filters, [1, 1], padding='SAME', activation_fn=activation_fn, scope=scope)

def separable_conv2d(input_tensor, filters, kernel_size, strids=[1, 1], padding='VALID', activation_fn=None, scope=None):
    scope = scope if not scope is None else 'separable_conv2d'
    depthwise_conv2d = depthwise_conv2d_splite_share
    l = depthwise_conv2d(input_tensor, kernel_size, strids, padding, scope=scope+'_depthwise')
    l = pointwise_conv2d(l, filters, activation_fn, scope=scope+'_pointwise')
    return l

# %%
from functools import reduce
from tensorflow.python.ops import gradients_impl
from tensorflow.python.ops import array_ops, tensor_array_ops, control_flow_ops

def hessians_highrank(ys, xs, gradients=None, name="hessians", colocate_gradients_with_ops=False,
            gate_gradients=False, aggregation_method=None):
  """Constructs the Hessian (one or more rank matrix) of sum of `ys` with respect to `x` in `xs`.
  `hessians_highrank()` adds ops to the graph to output the Hessian matrix of `ys`
  with respect to `xs`.  It returns a list of `Tensor` of length `len(xs)`
  where each tensor is the Hessian of `sum(ys)`. This function currently
  only supports evaluating the Hessian with respect to (a list of) one-
  dimensional tensors.
  The Hessian is a matrix of second-order partial derivatives of a scalar
  tensor (see https://en.wikipedia.org/wiki/Hessian_matrix for more details).
  Args:
    ys: A `Tensor` or list of tensors to be differentiated.
    xs: A `Tensor` or list of tensors to be used for differentiation.
    name: Optional name to use for grouping all the gradient ops together.
      defaults to 'hessians'.
    colocate_gradients_with_ops: See `gradients()` documentation for details.
    gate_gradients: See `gradients()` documentation for details.
    aggregation_method: See `gradients()` documentation for details.
  Returns:
    A list of Hessian matrices of `sum(ys)` for each `x` in `xs`.
  Raises:
    LookupError: if one of the operations between `xs` and `ys` does not
      have a registered gradient function.
  """
  xs = gradients_impl._AsList(xs)
  kwargs = {
    'colocate_gradients_with_ops': colocate_gradients_with_ops,
    'gate_gradients': gate_gradients,
    'aggregation_method': aggregation_method
  }
  # Compute first-order derivatives and iterate for each x in xs.
  hessians = []
  _gradients = tf.gradients(ys, xs, **kwargs) if gradients is None else gradients
  for i, _gradient, x in zip(range(len(xs)), _gradients, xs):
    shape = x.shape
    _gradient = tf.reshape(_gradient, [-1])
    
    n = tf.size(x)
    loop_vars = [
      array_ops.constant(0, tf.int32),
      tensor_array_ops.TensorArray(x.dtype, n)
    ]
    _, hessian = control_flow_ops.while_loop(
      lambda j, _: j < n,
      lambda j, result: (j + 1, result.write(j, tf.gradients(_gradient[j], x)[0])),
      loop_vars
    )
    hessians.append(hessian.stack())
  return hessians

# %%
import time
import cv2
import numpy as np
import tensorflow as tf
import tensorpack as tp

from tensorpack import dataset
from tensorpack.dataflow import imgaug, AugmentImageComponent, BatchData, PrefetchData
import tensorpack.tfutils.symbolic_functions as symbf

import tensorflow.contrib.slim as slim
from tensorflow.python.framework import ops
from tensorflow.python.training import optimizer

class ModelMNIST10x10_simple(object):
    def __init__(self, learning_rate=1.0, batch_size=128, momentum=0.9):
        self.batch_size = batch_size
        self.inputs = [
            tf.placeholder(tf.float32, shape=(None, 10, 10, 1)),
            tf.placeholder(tf.int32, shape=(None,)),
            tf.placeholder(tf.float32, shape=(None, 10))
        ]
        
        self.probability, self.cost, self.accuracy = self._build_graph(self.inputs)
        self.op = self._get_optimize_operator(self.cost, learning_rate, momentum)
        self.dataflow = {
            'train':self._get_data('train'),
            'valid':self._get_data('test'),
        }
        
    def _build_graph(self, inputs):
        image, label, vector = inputs
        
        with slim.arg_scope([slim.layers.fully_connected], weights_regularizer=slim.l2_regularizer(1e-5)):
            l = image
            l = separable_conv2d(l, 8, [3, 3], padding='SAME', activation_fn=tf.nn.relu, scope='conv0')
            l = slim.layers.max_pool2d(l, [2, 2], scope='pool0') # 5x5
            l = separable_conv2d(l, 8, [3, 3], padding='VALID', activation_fn=tf.nn.relu, scope='conv1')
            l = separable_conv2d(l, 8, [3, 3], padding='VALID', activation_fn=tf.nn.relu, scope='conv2')
            l = slim.layers.flatten(l, scope='flatten')
            logits = slim.layers.fully_connected(l, 10, activation_fn=None, scope='fc0')

        # Currently there is no way to take the second derivative of sparse_softmax_cross_entropy_with_logits due to the fused implementation
        #cost = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=label)
        cost = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=vector)
        cost = tf.reduce_mean(cost, name='cross_entropy_loss')

        prob = tf.nn.softmax(logits, name='prob')
        accuracy = symbf.accuracy(logits, label, topk=1)
        return prob, cost, accuracy
    
    def _get_optimize_operator(self, cost, learning_rate=1.0, momentum=0.9):
        var_list = (tf.trainable_variables() + tf.get_collection(tf.GraphKeys.TRAINABLE_RESOURCE_VARIABLES))
        var_list += tf.get_collection(tf.GraphKeys._STREAMING_MODEL_PORTS)

        processors = [optimizer._get_processor(v) for v in var_list]
        var_refs = [p.target() for p in processors]

        # compute_gradients
        grads = tf.gradients(
                cost, var_refs,
                grad_ys=None, aggregation_method=None, colocate_gradients_with_ops=True)
        #grads_and_vars = list(zip(grads, var_list))

        hessis = hessians_highrank(
                 cost, var_refs, gradients=grads,
                 aggregation_method=None, colocate_gradients_with_ops=True)
        
        second_order_grads = []
        for g, h in zip(grads, hessis):
            shape = g.shape
            d = int(reduce(lambda a,b: a*b, shape))

            g = tf.reshape(g, [d, 1])
            h = tf.reshape(h, [d, d]) + (tf.eye(d) * 1e-2)
            h_inv = tf.matrix_inverse(h)
            grad = tf.matmul(h_inv, g)
            grad = tf.reshape(grad, shape)
            second_order_grads.append(grad)
        grads_and_vars = list(zip(second_order_grads, var_list))

        self.grads = grads
        
        self.global_step = tf.contrib.framework.get_or_create_global_step()
        lr_schedule = {
            'step':     [                   1],
            'rate':     [0.1*learning_rate, learning_rate],
        }
        lr_schedule['step'] = ops.convert_n_to_tensor(lr_schedule['step'], tf.int64)
        learning_rate = tf.train.piecewise_constant(self.global_step, lr_schedule['step'], lr_schedule['rate'])
        #opt = tf.train.AdamOptimizer(learning_rate)
        opt = tf.train.MomentumOptimizer(learning_rate, momentum, use_nesterov=True)
        #opt = tf.train.GradientDescentOptimizer(learning_rate)
        return opt.apply_gradients(grads_and_vars)
    
    def _get_data(self, train_or_test):
        BATCH_SIZE = self.batch_size
        isTrain = train_or_test == 'train'
        ds = dataset.Mnist(train_or_test)
        if isTrain:
            augmentors = [
                #imgaug.RandomApplyAug(imgaug.RandomResize((0.8, 1.2), (0.8, 1.2)), 0.3),
                #imgaug.RandomApplyAug(imgaug.RotationAndCropValid(15), 0.5),
                #imgaug.RandomApplyAug(imgaug.SaltPepperNoise(white_prob=0.01, black_prob=0.01), 0.25),
                imgaug.Resize((10, 10)),
                imgaug.CenterPaste((12, 12)),
                imgaug.RandomCrop((10, 10)),
                imgaug.MapImage(lambda x: x.reshape(10, 10, 1))
            ]
        else:
            augmentors = [
                imgaug.Resize((10, 10)),
                imgaug.MapImage(lambda x: x.reshape(10, 10, 1))
            ]
        ds = AugmentImageComponent(ds, augmentors)
        ds = BatchData(ds, BATCH_SIZE, remainder=not isTrain)
        if isTrain:
            ds = PrefetchData(ds, 3, 2)
        return ds

# %%
model = ModelMNIST10x10_simple(learning_rate=0.9, momentum=0.9, batch_size=128*100)
# Out:
# [1026 11:34:27 @fs.py:89] WRN Env var $TENSORPACK_DATASET not set, using /root/tensorpack_data for datasets.

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print('session initialized')
# Out:
# session initialized

# %%
import sklearn.preprocessing

history = []
for epoch in range(30):
    result = {}
    
    model.dataflow['train'].reset_state()
    step, costs, accuracies = 0, [], []
    
    timestamp = time.time()
    for datapoint in model.dataflow['train'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        _, cost, accuracy, grads = sess.run([model.op, model.cost, model.accuracy, model.grads],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        grads = [np.sum(np.abs(g)) for g in grads]
        costs.append(cost)
        accuracies.append(accuracy)
        step += 1
        #print('[train] epoch:%04d step:%04d cost:%.3f accuracy:%0.3f'%(epoch, step, cost, accuracy))
    eplapsed = time.time() - timestamp
    print('[%04d] [train] cost:%.3f accuracy:%0.3f elapsed:%.3fs'%(epoch+1, np.mean(costs), np.mean(accuracies), eplapsed), end=' ')
    result['train'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies), 'grads_abs':grads}

    model.dataflow['valid'].reset_state()
    costs, accuracies = [], []
    timestamp = time.time()
    for datapoint in model.dataflow['valid'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        cost, accuracy = sess.run([model.cost, model.accuracy],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        costs.append(cost)
        accuracies.append(accuracy)
    eplapsed = time.time() - timestamp
    print('[valid] cost:%.3f accuracy:%0.3f elapsed:%.3fs'%(np.mean(costs), np.mean(accuracies), eplapsed))
    result['valid'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies)}
    
    history.append( result )
# Out:
# [0001] [train] cost:0.507 accuracy:0.101 elapsed:4.192s [valid] cost:0.332 accuracy:0.103 elapsed:0.448s
# [0002] [train] cost:0.333 accuracy:0.104 elapsed:2.388s [valid] cost:0.331 accuracy:0.101 elapsed:0.310s
# [0003] [train] cost:0.329 accuracy:0.094 elapsed:2.383s [valid] cost:0.325 accuracy:0.117 elapsed:0.295s
# [0004] [train] cost:0.324 accuracy:0.137 elapsed:2.394s [valid] cost:0.321 accuracy:0.170 elapsed:0.304s
# [0005] [train] cost:0.317 accuracy:0.185 elapsed:2.362s [valid] cost:0.307 accuracy:0.181 elapsed:0.304s
# [0006] [train] cost:0.308 accuracy:0.196 elapsed:2.303s [valid] cost:0.298 accuracy:0.211 elapsed:0.282s
# [0007] [train] cost:0.298 accuracy:0.231 elapsed:2.313s [valid] cost:0.287 accuracy:0.250 elapsed:0.314s
# [0008] [train] cost:0.288 accuracy:0.260 elapsed:2.336s [valid] cost:0.278 accuracy:0.273 elapsed:0.285s
# [0009] [train] cost:0.280 accuracy:0.275 elapsed:2.353s [valid] cost:0.272 accuracy:0.289 elapsed:0.304s
# [0010] [train] cost:0.274 accuracy:0.293 elapsed:2.352s [valid] cost:0.269 accuracy:0.294 elapsed:0.305s
# [0011] [train] cost:0.269 accuracy:0.313 elapsed:2.350s [valid] cost:0.261 accuracy:0.339 elapsed:0.298s
# [0012] [train] cost:0.262 accuracy:0.338 elapsed:2.358s [valid] cost:0.254 accuracy:0.365 elapsed:0.299s
# [0013] [train] cost:0.257 accuracy:0.355 elapsed:2.378s [valid] cost:0.246 accuracy:0.398 elapsed:0.302s
# [0014] [train] cost:0.253 accuracy:0.373 elapsed:2.383s [valid] cost:0.242 accuracy:0.407 elapsed:0.302s
# [0015] [train] cost:0.247 accuracy:0.390 elapsed:2.378s [valid] cost:0.239 accuracy:0.413 elapsed:0.281s
# [0016] [train] cost:0.241 accuracy:0.408 elapsed:2.366s [valid] cost:0.237 accuracy:0.419 elapsed:0.280s
# [0017] [train] cost:0.239 accuracy:0.413 elapsed:2.380s [valid] cost:0.235 accuracy:0.426 elapsed:0.303s
# [0018] [train] cost:0.236 accuracy:0.426 elapsed:2.370s [valid] cost:0.232 accuracy:0.443 elapsed:0.280s
# [0019] [train] cost:0.233 accuracy:0.452 elapsed:2.379s [valid] cost:0.229 accuracy:0.463 elapsed:0.303s
# [0020] [train] cost:0.230 accuracy:0.462 elapsed:2.373s [valid] cost:0.227 accuracy:0.476 elapsed:0.275s
# [0021] [train] cost:0.228 accuracy:0.474 elapsed:2.382s [valid] cost:0.226 accuracy:0.486 elapsed:0.298s
# [0022] [train] cost:0.225 accuracy:0.486 elapsed:2.379s [valid] cost:0.225 accuracy:0.494 elapsed:0.278s
# [0023] [train] cost:0.223 accuracy:0.493 elapsed:2.388s [valid] cost:0.221 accuracy:0.502 elapsed:0.281s
# [0024] [train] cost:0.221 accuracy:0.498 elapsed:2.386s [valid] cost:0.221 accuracy:0.510 elapsed:0.299s
# [0025] [train] cost:0.220 accuracy:0.502 elapsed:2.387s [valid] cost:0.219 accuracy:0.518 elapsed:0.301s
# [0026] [train] cost:0.219 accuracy:0.502 elapsed:2.381s [valid] cost:0.217 accuracy:0.524 elapsed:0.281s
# [0027] [train] cost:0.218 accuracy:0.510 elapsed:2.380s [valid] cost:0.215 accuracy:0.532 elapsed:0.278s
# [0028] [train] cost:0.217 accuracy:0.508 elapsed:2.382s [valid] cost:0.215 accuracy:0.536 elapsed:0.622s
# [0029] [train] cost:0.216 accuracy:0.513 elapsed:2.390s [valid] cost:0.213 accuracy:0.539 elapsed:0.278s
# [0030] [train] cost:0.215 accuracy:0.519 elapsed:2.390s [valid] cost:0.213 accuracy:0.537 elapsed:0.297s

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(12, 4*3))
for i, label in enumerate(['cost', 'accuracy', 'grads_abs']):
    ax = fig.add_subplot(3, 1, i+1)
    ax.set_xlabel('epoch', fontsize=12)
    ax.set_ylabel(label, fontsize=12)
    ax.set_title(label, fontsize=12)
    for j, mode in enumerate(['train', 'valid']):
        if not label in history[0][mode]:
            continue
        ax.plot(np.array([h[mode]['epoch'] for h in history]), np.array([np.sum(h[mode][label]) for h in history]), label=mode)
    ax.legend()
plt.tight_layout()

# %%
for epoch in range(30):
    result = {}
    
    model.dataflow['train'].reset_state()
    step, costs, accuracies = 0, [], []
    
    timestamp = time.time()
    for datapoint in model.dataflow['train'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        _, cost, accuracy, grads = sess.run([model.op, model.cost, model.accuracy, model.grads],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        grads = [np.sum(np.abs(g)) for g in grads]
        costs.append(cost)
        accuracies.append(accuracy)
        step += 1
        #print('[train] epoch:%04d step:%04d cost:%.3f accuracy:%0.3f'%(epoch, step, cost, accuracy))
    eplapsed = time.time() - timestamp
    print('[%04d] [train] cost:%.3f accuracy:%0.3f elapsed:%.3fs'%(epoch+1, np.mean(costs), np.mean(accuracies), eplapsed), end=' ')
    result['train'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies), 'grads_abs':grads}

    model.dataflow['valid'].reset_state()
    costs, accuracies = [], []
    timestamp = time.time()
    for datapoint in model.dataflow['valid'].get_data():
        datapoint.append( sklearn.preprocessing.label_binarize( datapoint[1], range(10) ).astype(np.float32) )
        cost, accuracy = sess.run([model.cost, model.accuracy],
                                     feed_dict=dict(zip(model.inputs, datapoint)))
        costs.append(cost)
        accuracies.append(accuracy)
    eplapsed = time.time() - timestamp
    print('[valid] cost:%.3f accuracy:%0.3f elapsed:%.3fs'%(np.mean(costs), np.mean(accuracies), eplapsed))
    result['valid'] = {'epoch':epoch, 'cost':np.mean(costs), 'accuracy':np.mean(accuracies)}
    
    history.append( result )
# Out:
# [0001] [train] cost:0.215 accuracy:0.520 elapsed:2.385s [valid] cost:0.211 accuracy:0.543 elapsed:0.286s
# [0002] [train] cost:0.213 accuracy:0.523 elapsed:2.394s [valid] cost:0.211 accuracy:0.543 elapsed:0.280s
# [0003] [train] cost:0.213 accuracy:0.522 elapsed:2.390s [valid] cost:0.209 accuracy:0.552 elapsed:0.283s
# [0004] [train] cost:0.212 accuracy:0.525 elapsed:2.390s [valid] cost:0.208 accuracy:0.551 elapsed:0.285s
# [0005] [train] cost:0.211 accuracy:0.531 elapsed:2.393s [valid] cost:0.208 accuracy:0.554 elapsed:0.293s
# [0006] [train] cost:0.210 accuracy:0.533 elapsed:2.383s [valid] cost:0.206 accuracy:0.556 elapsed:0.281s
# [0007] [train] cost:0.209 accuracy:0.534 elapsed:2.388s [valid] cost:0.205 accuracy:0.557 elapsed:0.305s
# [0008] [train] cost:0.209 accuracy:0.537 elapsed:2.408s [valid] cost:0.204 accuracy:0.563 elapsed:0.305s
# [0009] [train] cost:0.208 accuracy:0.537 elapsed:2.390s [valid] cost:0.203 accuracy:0.564 elapsed:0.347s
# [0010] [train] cost:0.207 accuracy:0.541 elapsed:2.394s [valid] cost:0.203 accuracy:0.563 elapsed:0.289s
# [0011] [train] cost:0.207 accuracy:0.540 elapsed:2.409s [valid] cost:0.203 accuracy:0.563 elapsed:0.363s
# [0012] [train] cost:0.207 accuracy:0.543 elapsed:2.388s [valid] cost:0.204 accuracy:0.564 elapsed:0.281s
# [0013] [train] cost:0.206 accuracy:0.543 elapsed:2.386s [valid] cost:0.204 accuracy:0.562 elapsed:0.303s
# [0014] [train] cost:0.206 accuracy:0.544 elapsed:2.402s [valid] cost:0.202 accuracy:0.566 elapsed:0.342s
# [0015] [train] cost:0.205 accuracy:0.546 elapsed:2.387s [valid] cost:0.202 accuracy:0.566 elapsed:0.280s
# [0016] [train] cost:0.205 accuracy:0.544 elapsed:2.383s [valid] cost:0.204 accuracy:0.564 elapsed:0.323s
# [0017] [train] cost:0.205 accuracy:0.549 elapsed:2.395s [valid] cost:0.204 accuracy:0.562 elapsed:0.285s
# [0018] [train] cost:0.205 accuracy:0.549 elapsed:2.390s [valid] cost:0.203 accuracy:0.564 elapsed:0.279s
# [0019] [train] cost:0.204 accuracy:0.550 elapsed:2.382s [valid] cost:0.202 accuracy:0.563 elapsed:0.288s
# [0020] [train] cost:0.204 accuracy:0.547 elapsed:2.385s [valid] cost:0.203 accuracy:0.560 elapsed:0.304s
# [0021] [train] cost:0.203 accuracy:0.554 elapsed:2.386s [valid] cost:0.202 accuracy:0.561 elapsed:0.326s
# [0022] [train] cost:0.202 accuracy:0.551 elapsed:2.399s [valid] cost:0.202 accuracy:0.563 elapsed:0.330s
# [0023] [train] cost:0.201 accuracy:0.556 elapsed:2.381s [valid] cost:0.202 accuracy:0.563 elapsed:0.332s
# [0024] [train] cost:0.201 accuracy:0.557 elapsed:2.382s [valid] cost:0.201 accuracy:0.564 elapsed:0.337s
# [0025] [train] cost:0.200 accuracy:0.560 elapsed:2.388s [valid] cost:0.200 accuracy:0.566 elapsed:0.328s
# [0026] [train] cost:0.201 accuracy:0.555 elapsed:2.380s [valid] cost:0.200 accuracy:0.569 elapsed:0.278s
# [0027] [train] cost:0.199 accuracy:0.562 elapsed:2.377s [valid] cost:0.201 accuracy:0.568 elapsed:0.279s
# [0028] [train] cost:0.199 accuracy:0.562 elapsed:2.380s [valid] cost:0.199 accuracy:0.569 elapsed:0.303s
# [0029] [train] cost:0.199 accuracy:0.560 elapsed:2.381s [valid] cost:0.199 accuracy:0.572 elapsed:0.290s
# [0030] [train] cost:0.199 accuracy:0.562 elapsed:2.393s [valid] cost:0.200 accuracy:0.572 elapsed:0.282s

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(12, 4*3))
for i, label in enumerate(['cost', 'accuracy', 'grads_abs']):
    ax = fig.add_subplot(3, 1, i+1)
    ax.set_xlabel('epoch', fontsize=12)
    ax.set_ylabel(label, fontsize=12)
    ax.set_title(label, fontsize=12)
    for j, mode in enumerate(['train', 'valid']):
        if not label in history[0][mode]:
            continue
        ax.plot(np.array(range(len(history))), np.array([np.sum(h[mode][label]) for h in history]), label=mode)
    ax.legend()
plt.tight_layout()
